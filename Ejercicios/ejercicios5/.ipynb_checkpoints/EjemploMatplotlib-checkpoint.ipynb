# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import radviz

# %matplotlib inline

# %%
mi_df = pd.read_json('data/log-course2.json')
mi_df
# Out:
#                            accept_language  \
# 0                           es-ES,es;q=0.9
# 1                           es-ES,es;q=0.9
# 2      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 3      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 4      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 5      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 6      es-ES,es;q=0.8,en-US;q=0.5,en;q=0.3
# 7                           es-ES,es;q=0.9
# 8                           es-ES,es;q=0.9
# 9                           es-ES,es;q=0.9
# 10                          es-ES,es;q=0.9
# 11                          es-ES,es;q=0.9
# 12                          es-ES,es;q=0.9
# 13                          es-ES,es;q=0.9
# 14                          es-ES,es;q=0.9
# 15                          es-ES,es;q=0.9
# 16                          es-ES,es;q=0.9
# 17                          es-ES,es;q=0.9
# 18                          es-ES,es;q=0.9
# 19                          es-ES,es;q=0.9
# 20                          es-ES,es;q=0.9
# ...

# %%
mi_df.keys()
# Out:
# Index(['accept_language', 'agent', 'context', 'event', 'event_source',
#        'event_type', 'host', 'ip', 'name', 'page', 'referer', 'session',
#        'time', 'username'],
#       dtype='object')

# %%
mi_df.username.unique()
# Out:
# array(['', 'danieltapia00', 'JocelyneCastillo', ..., 'esbravo3',
#        'dmandrade1', 'KAELIZALDE'], dtype=object)

# %%
mi_df.name.unique()
# Out:
# array([nan, 'edx.course.enrollment.activated',
#        'edx.course.enrollment.deactivated', 'page_close', 'load_video',
#        'play_video', 'pause_video', 'seek_video',
#        'edx.forum.thread.created', 'problem_check', 'problem_graded',
#        'seq_goto', 'edx.forum.response.created', 'problem_show',
#        'problem_save', 'edx.user.settings.changed', 'seq_next',
#        'seq_prev', 'edx.forum.comment.created', 'stop_video',
#        'edx.forum.searched', 'speed_change_video'], dtype=object)

# %%
mi_df.username.value_counts()[1:15].sort_values(inplace=False).plot(kind='bar', title= 'Grafico1');

# %%
mi_df.name.value_counts()[1:15].sort_values(inplace=False).plot(kind='barh', title= 'Grafico2');

# %%
mi_df[mi_df['name'].str.strip()=='load_video'].username.value_counts()[:6].sort_values(inplace=False).plot(kind='barh', title=u'Gráfico3');
plt.ylabel('USERNAMES')
# Out:
# Text(0, 0.5, 'USERNAMES')

# %%
lista = mi_df.name.value_counts()
